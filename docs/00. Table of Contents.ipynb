# %% [markdown]
# 1. PyCharm Overview
#     - Creating a project in PyCharm. Virtual environments
#     - User Interface. Main windows
#     - Code formatting and inspections in PyCharm
#     - Version control integration: `git` in PyCharm
# 2. Control Flow
#     - Walrus operator
#     - Match expressions
# 3. More on Functions and Iterables
#     - Functions with variable-length arguments
#     - Variable unpacking
#     - Comprehensions for lists, sets, and dictionaries
#     - Iterators and generators
#     - Anonymous functions (lambdas)
#     - Built-in functions: `filter`, `map`, `enumerate`, `sorted`, `zip`
#     - Advanced iteration with the `itertools` module
# 4. Advanced Data Structures
#     - Advanced structures: `namedtuple` and `defaultdict`
#     - Understanding and using `deque`, `OrderedDict`, and `Counter`
# 5. Decorators
#     - Understanding functions' roles and uses
#     - Creating simple decorators
#     - Implementing decorators with arguments
# 6. Object-Oriented Programming
#     - Dunder (magic) methods and attributes, including operator overloading
#     - Static and class methods
#     - Getter/Setter methods and the property class
#     - Introduction to metaclasses
#     - Common design patterns in Python
# 7. Context Managers
#     - Using the `with` statement
#     - Creating custom context managers with the `contextlib` module
# 8. Working with different data formats
#     - File manipulation using `open` built-in function
#     - Working with JSON format (Standard Library module `json`)
#     - Working with CSV format (Standard Library module `csv`)
#     - Working with Excel files (3rd party module: `openpyxl`)
#     - Working with XML format (Standard Library module `xml.etree.ElementTree` and 3rd party module `BeautifulSoup`)
#     - Data Analysis with `pandas`
# 9. Working with databases
#     - Working with raw SQL (DB-API 2.0 and packages compliant to the specification)
#     - Managing databases through Python code: ORMs
# 10. Testing Your Code
#     - Importance of testing
#     - Types of testing
#     - Using testing frameworks: `unittest` and `pytest`
# 11. Logging
#     - Basic logging configurations
#     - Understanding loggers, handlers, and formatters
#     - Advanced logging techniques
#     - Formatting log output
# 12. Concurrent Execution
#     - Using the `threading` module
#     - Utilizing the `multiprocessing` module
# 13. Other useful modules
#     - Communicating with external processes (`subprocess` module)
#     - System-specific parameters and functions (`sys` module)
# 14. GUI automation
#     - Web Automation with Selenium
#     - Android Automation with Appium
# 15. Android API used with Python (`pyjnius`)
# 16. Building Dashboards in Python (`dash`)
